# %%
import mysql.connector
from mysql.connector import errorcode

# %%
config = {
  'user': 'aura',
  'password': 'aura-mfg',
  'host': '173.194.232.122',
  'database': 'aura_mfg',
  'raise_on_warnings': True,
}

# %%
FF_SID = {}

try:
    cnx = mysql.connector.connect(**config)
    cursor = cnx.cursor()
    query = "SELECT * FROM camera_sfr"
    cursor.execute(query)
    count = 0
    for line in cursor:
        if line[4] not in FF_SID:
            FF_SID[line[4]] = 1
            count += 1
        else:
            FF_SID[line[4]] += 1

    print("The total number of device is %d" % count)
    for k, v in FF_SID.items():
        print (k, v)
    cursor.close()
    cnx.close()
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Password does NOT match")
    else:
        print("Something went wrong: {}".format(err))
finally:
    exit()
# Out:
# The total number of device is 330
# (u'BSJ1P0M116190317', 8)
# (u'BSJ1P0M116190316', 5)
# (u'BSJ1P0M516230739', 1)
# (u'BSJ1P0M116190314', 2)
# (u'BSJ1P0M116190313', 1)
# (u'BSJ1P0M116190312', 1)
# (u'BSJ1P0M116190311', 1)
# (u'BSJ1P0M916232719', 17)
# (u'BSJ1P0M916232716', 3)
# (u'BSJ1P0M916232717', 3)
# (u'BSJ1P0M916232714', 1)
# (u'BSJ1P0M916232715', 3)
# (u'BSJ1P0M916232712', 11)
# (u'BSJ1P0M916232713', 1)
# (u'BSJ1P0M116190319', 5)
# (u'BSJ1P0M116190318', 5)
# (u'BSJ1P0MA16222339', 2)
# (u'BSJ1P0MA16222338', 6)
# (u'BSJ1P0M916232744', 2)
# (u'BSJ1P0MA16222331', 2)
# (u'BSJ1P0MA16222330', 1)
# (u'BSJ1P0MA16222333', 1)
# (u'BSJ1P0MA16222332', 17)
# (u'BSJ1P0MA16222335', 2)
# (u'BSJ1P0MA16222334', 2)
# (u'BSJ1P0MA16222337', 2)
# (u'BSJ1P0MA16222336', 2)
# (u'BSJ1P0M216190412', 1)
# (u'BSJ1P0M216190410', 4)
# (u'BSJ1P0M216190416', 2)
# (u'BSJ1P0M216190415', 5)
# (u'BSJ1P0M216190414', 7)
# (u'BSJ1P0M516230720', 1)
# (u'BSJ1P0M216190419', 2)
# (u'BSJ1P0M216190418', 1)
# (u'BSJ1P0M816231014', 1)
# (u'BSJ1P0M116190328', 2)
# (u'BSJ1P0M116190329', 1)
# (u'BSJ1P0M516230722', 3)
# (u'BSJ1P0M916232729', 2)
# (u'BSJ1P0M516230753', 1)
# (u'BSJ1P0M116190322', 3)
# (u'BSJ1P0M116190323', 5)
# (u'BSJ1P0M116190320', 1)
# (u'BSJ1P0M116190321', 1)
# (u'BSJ1P0M116190326', 17)
# (u'BSJ1P0M116190327', 4)
# (u'BSJ1P0M116190324', 4)
# (u'BSJ1P0M116190325', 2)
# (u'BSJ1P0M916232701', 2)
# (u'BSJ1P0DA16232001', 2)
# (u'BSJ1P0M916232703', 1)
# (u'BSJ1P0M916232702', 1)
# (u'BSJ1P0M916232705', 2)
# (u'BSJ1P0M916232704', 3)
# (u'BSJ1P0M916232707', 1)
# (u'BSJ1P0M916232706', 2)
# (u'BSJ1P0M916232709', 2)
# (u'BSJ1P0M916232708', 2)
# (u'BSJ1P0M916232710', 2)
# (u'BSJ1P0M916232711', 4)
# (u'BSJ1P0MA16222340', 1)
# (u'BSJ1P0M416230604', 1)
# (u'BSJ1P0M216190426', 7)
# (u'BSJ1P0M216190427', 1)
# (u'BSJ1P0M216190424', 1)
# (u'BSJ1P0M216190425', 1)
# (u'BSJ1P0M216190422', 3)
# (u'BSJ1P0M216190423', 3)
# (u'BSJ1P0M216190420', 1)
# (u'BSJ1P0M216190421', 1)
# (u'BSJ1P0M816231006', 2)
# (u'BSJ1P0M816231007', 1)
# (u'BSJ1P0M816231004', 2)
# (u'BSJ1P0M816231005', 2)
# (u'BSJ1P0M816231002', 1)
# (u'BSJ1P0M816231003', 3)
# (u'BSJ1P0M216190428', 1)
# (u'BSJ1P0M216190429', 2)
# (u'????????????', 1)
# (u'BSJ1P0D116231101', 2)
# (u'BSJ1P0M816231009', 2)
# (u'BSJ1P0M516230770', 2)
# (u'BSJ1P0M516230732', 2)
# (u'BSJ1P0M416230601', 1)
# (u'BSJ1P0M116190339', 6)
# (u'BSJ1P0M116190338', 3)
# (u'BSJ1P0M116190334', 3)
# (u'BSJ1P0M116190337', 5)
# (u'BSJ1P0M116190336', 3)
# (u'BSJ1P0M116190331', 1)
# (u'BSJ1P0M116190330', 3)
# (u'BSJ1P0M116190333', 2)
# (u'BSJ1P0M516230777', 2)
# (u'BSJ1P0M516230736', 2)
# (u'BSJ1P0N416222602', 1)
# (u'BSJ1P0M316220507', 2)
# (u'BSJ1P0M516230737', 2)
# (u'BSJ1P0M516230775', 2)
# (u'BSJ1P0M516230733', 2)
# (u'BSJ1P0M516230734', 3)
# (u'BSJ1P0D916241903', 1)
# (u'BSJ1P0M516230721', 3)
# (u'BSJ1P0M216190438', 5)
# (u'BSJ1P0M516230723', 1)
# (u'BSJ1P0M516230735', 1)
# (u'BSJ1P0M516230725', 2)
# (u'BSJ1P0M416230605', 3)
# (u'BSJ1P0M516230727', 2)
# (u'BSJ1P0M516230726', 1)
# (u'BSJ1P0M216190431', 2)
# (u'BSJ1P0M216190430', 1)
# (u'BSJ1P0M216190433', 4)
# (u'BSJ1P0M216190432', 3)
# (u'BSJ1P0M216190435', 1)
# (u'BSJ1P0M216190434', 1)
# (u'BSJ1P0M216190437', 1)
# (u'BSJ1P0M216190436', 3)
# (u'BSJ1P0M816231011', 2)
# (u'BSJ1P0M816231010', 1)
# (u'BSJ1P0M816231013', 2)
# (u'BSJ1P0M816231015', 1)
# (u'BSJ1P0M516230730', 2)
# (u'BSJ1P0M816231017', 2)
# (u'BSJ1P0M816231016', 2)
# (u'BSJ1P0M816231019', 3)
# (u'BSJ1P0M816231018', 2)
# (u'BSJ1P0N416222614', 1)
# (u'BSJ1P0N416222615', 3)
# (u'BSJ1P0N416222612', 1)
# (u'BSJ1P0N416222613', 2)
# (u'BSJ1P0N416222610', 1)
# (u'BSJ1P0N416222611', 4)
# (u'BSJ1P0M416230603', 4)
# (u'BSJ1P0M416230602', 2)
# (u'BSJ1P0N416222603', 1)
# (u'LIST OF DEVICES ATTACHED ', 68)
# (u'BSJ1P0N416222605', 3)
# (u'BSJ1P0N416222604', 1)
# (u'BSJ1P0N416222607', 2)
# (u'BSJ1P0N416222606', 3)
# (u'BSJ1P0N416222609', 2)
# (u'BSJ1P0N416222608', 3)
# (u'BSJ1P0M916232726', 3)
# (u'BSJ1P0M516230731', 1)
# (u'BSJ1P0M316220503', 2)
# (u'BSJ1P0M916232733', 2)
# (u'BSJ1P0M516230754', 2)
# (u'BSJ1P0N316222505', 2)
# (u'BSJ1P0M516230756', 1)
# (u'BSJ1P0M516230757', 2)
# (u'BSJ1P0M516230750', 1)
# (u'BSJ1P0M516230751', 1)
# (u'BSJ1P0M516230752', 1)
# (u'BSJ1P0MA16222327', 3)
# (u'BSJ1P0M216190440', 1)
# (u'BSJ1P0N316222507', 1)
# (u'BSJ1P0D916241901', 6)
# (u'BSJ1P0MA16222325', 1)
# (u'BSJ1P0M116190340', 2)
# (u'BSJ1P0MA16222322', 1)
# (u'BSJ1P0M516230729', 1)
# (u'BSJ1P0M516230711', 2)
# (u'BSJ1P0M916232738', 1)
# (u'BSJ1P0M516230759', 1)
# (u'BSJ1P0N316222503', 3)
# (u'BSJ1P0M516230706', 2)
# (u'BSJ1P0N316222502', 1)
# (u'BSJ1P0M316220501', 2)
# (u'BSJ1P0M516230748', 1)
# (u'BSJ1P0D116231104', 2)
# (u'BSJ1P0N416222601', 2)
# (u'BSJ1P0M516230746', 4)
# (u'BSJ1P0M516230745', 2)
# (u'BSJ1P0M516230744', 3)
# (u'BSJ1P0M516230743', 2)
# (u'BSJ1P0M516230742', 2)
# (u'BSJ1P0M516230741', 1)
# (u'BSJ1P0M516230740', 2)
# (u'BSJ1P0M516230707', 1)
# (u'BSJ1P0M816231001', 2)
# (u'BSJ1P0M516230709', 2)
# (u'BSJ1P0M516230749', 2)
# (u'BSJ1P0M516230747', 2)
# (u'BSJ1P0N216180222', 6)
# (u'BSJ1P0N216180223', 1)
# (u'BSJ1P0M516230758', 2)
# (u'BSJ1P0M516230705', 1)
# (u'BSJ1P0D116231108', 1)
# (u'BSJ1P0M516230704', 3)
# (u'BSJ1P0M516230710', 1)
# (u'BSJ1P0M516230755', 2)
# (u'BSJ1P0MA16222301', 4)
# (u'BSJ1P0N116180104', 3)
# (u'BSJ1P0MA16222303', 8)
# (u'BSJ1P0N116180102', 11)
# (u'BSJ1P0N116180103', 6)
# (u'BSJ1P0MA16222306', 1)
# (u'BSJ1P0MA16222307', 2)
# (u'BSJ1P0MA16222308', 3)
# (u'BSJ1P0MA16222309', 2)
# (u'BSJ1P0M916232741', 3)
# (u'BSJ1P0M916232740', 2)
# (u'BSJ1P0M916232743', 1)
# (u'BSJ1P0M916232742', 4)
# (u'BSJ1P0M916232745', 1)
# (u'BSJ1P0MA16222313', 2)
# (u'BSJ1P0M516230778', 2)
# (u'BSJ1P0M516230779', 3)
# (u'BSJ1P0M516230719', 4)
# (u'BSJ1P0MA16222312', 2)
# (u'BSJ1P0M516230772', 2)
# (u'BSJ1P0M516230773', 1)
# (u'BSJ1P0M916232718', 1)
# (u'BSJ1P0M516230771', 1)
# (u'BSJ1P0M516230776', 2)
# (u'BSJ1P0MA16222311', 1)
# (u'BSJ1P0M516230774', 2)
# (u'BSJ1P0M516230708', 2)
# (u'BSJ1P0M516230724', 3)
# (u'BSJ1P0M816231020', 1)
# (u'BSJ1P0N316222511', 3)
# (u'BSJ1P0M916232727', 1)
# (u'BSJ1P0M916232739', 1)
# (u'BSJ1P0D116231103', 1)
# (u'BSJ1P0D116231102', 2)
# (u'BSJ1P0D116231105', 2)
# (u'BSJ1P0N316222514', 2)
# (u'BSJ1P0D116231107', 2)
# (u'BSJ1P0D116231106', 1)
# (u'BSJ1P0M916232730', 1)
# (u'BSJ1P0M916232731', 7)
# (u'BSJ1P0M916232732', 2)
# (u'BSJ1P0MA16222314', 2)
# (u'BSJ1P0M916232734', 1)
# (u'BSJ1P0M916232735', 2)
# (u'BSJ1P0M916232736', 2)
# (u'BSJ1P0M916232737', 2)
# (u'BSJ1P0N316222512', 1)
# (u'BSJ1P0N316222513', 1)
# (u'BSJ1P0N316222510', 4)
# (u'BSJ1P0MA16222310', 3)
# (u'BSJ1P0MA16222317', 1)
# (u'BSJ1P0MA16222316', 1)
# (u'BSJ1P0MA16222315', 1)
# (u'BSJ1P0N316222515', 1)
# (u'BSJ1P0N116180111', 4)
# (u'BSJ1P0N116180110', 4)
# (u'BSJ1P0MA16222319', 2)
# (u'BSJ1P0MA16222318', 1)
# (u'BSJ1P0M516230714', 1)
# (u'BSJ1P0M516230715', 2)
# (u'BSJ1P0M516230716', 2)
# (u'BSJ1P0M516230717', 2)
# (u'BSJ1P0M516230713', 2)
# (u'BSJ1P0M516230769', 1)
# (u'BSJ1P0M516230768', 2)
# (u'BSJ1P0M316220502', 1)
# (u'BSJ1P0M516230765', 1)
# (u'BSJ1P0M516230764', 11)
# (u'BSJ1P0M516230767', 2)
# (u'BSJ1P0M516230766', 2)
# (u'BSJ1P0M516230761', 1)
# (u'BSJ1P0M516230760', 1)
# (u'BSJ1P0M516230763', 2)
# (u'BSJ1P0M516230762', 1)
# (u'BSJ1P0N216180206', 1)
# (u'BSJ1P0N216180207', 2)
# (u'BSJ1P0N216180205', 3)
# (u'BSJ1P0N216180202', 3)
# (u'BSJ1P0N216180203', 5)
# (u'BSJ1P0N216180201', 2)
# (u'BSJ1P0M316220506', 3)
# (u'BSJ1P0DA16232002', 1)
# (u'BSJ1P0N216180208', 2)
# (u'BSJ1P0N216180209', 4)
# (u'BSJ1P0M116190304', 5)
# (u'BSJ1P0M116190305', 1)
# (u'BSJ1P0M116190306', 3)
# (u'BSJ1P0M916232728', 1)
# (u'BSJ1P0D916241902', 1)
# (u'BSJ1P0M116190301', 8)
# (u'BSJ1P0M116190302', 4)
# (u'BSJ1P0M116190303', 2)
# (u'BSJ1P0M916232723', 2)
# (u'BSJ1P0M916232722', 2)
# (u'BSJ1P0M916232721', 2)
# (u'BSJ1P0M916232720', 5)
# (u'BSJ1P0M116190308', 6)
# (u'BSJ1P0M116190309', 4)
# (u'BSJ1P0M916232725', 4)
# (u'BSJ1P0M916232724', 1)
# (u'BSJ1P0MA16222326', 3)
# (u'BSJ1P0N316222504', 4)
# (u'BSJ1P0MA16222324', 5)
# (u'BSJ1P0N316222506', 1)
# (u'BSJ1P0N316222501', 2)
# (u'BSJ1P0MA16222323', 3)
# (u'BSJ1P0MA16222320', 5)
# (u'BSJ1P0N216180210', 1)
# (u'BSJ1P0M516230703', 2)
# (u'BSJ1P0M516230702', 2)
# (u'BSJ1P0M516230701', 1)
# (u'BSJ1P0N316222509', 1)
# (u'BSJ1P0N316222508', 3)
# (u'BSJ1P0MA16222328', 5)
# (u'BSJ1P0MA16222329', 2)
# (u'BSJ1P0M216190401', 1)
# (u'BSJ1P0M216190402', 2)
# (u'BSJ1P0M216190403', 1)
# (u'BSJ1P0M216190404', 1)
# (u'BSJ1P0M316220504', 3)
# (u'BSJ1P0M816231008', 2)
# (u'BSJ1P0M216190407', 1)
# (u'BSJ1P0M216190408', 1)
# (u'BSJ1P0M216190409', 4)
# (u'BSJ1P0M316220505', 2)
# (u'BSJ1P0MA16222302', 3)
# (u'BSJ1P0N216180219', 1)
# (u'BSJ1P0N216180218', 1)
# (u'BSJ1P0M516230718', 1)
# (u'BSJ1P0MA16222321', 1)
# (u'BSJ1P0M516230728', 2)
# (u'BSJ1P0N216180211', 24)
# (u'BSJ1P0MA16222304', 1)
# (u'BSJ1P0N216180213', 1)
# (u'BSJ1P0N216180212', 1)
# (u'BSJ1P0M316220508', 2)
# (u'BSJ1P0N216180217', 2)
# (u'BSJ1P0MA16222305', 1)
