# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline

# %%
oo = pd.read_csv(r'c:/Users/fanchang/Downloads/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# # show oo

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %% [markdown]
# # access series

# %%
oo['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
oo[['City', 'Edition' ]]
# Out:
#           City  Edition
# 0       Athens     1896
# 1       Athens     1896
# 2       Athens     1896
# 3       Athens     1896
# 4       Athens     1896
# 5       Athens     1896
# 6       Athens     1896
# 7       Athens     1896
# 8       Athens     1896
# 9       Athens     1896
# 10      Athens     1896
# 11      Athens     1896
# 12      Athens     1896
# 13      Athens     1896
# 14      Athens     1896
# 15      Athens     1896
# 16      Athens     1896
# 17      Athens     1896
# 18      Athens     1896
# 19      Athens     1896
# 20      Athens     1896
# 21      Athens     1896
# 22      Athens     1896
# 23      Athens     1896
# 24      Athens     1896
# 25      Athens     1896
# 26      Athens     1896
# 27      Athens     1896
# 28      Athens     1896
# 29      Athens     1896
# ...        ...      ...
# 29186  Beijing     2008
# 29187  Beijing     2008
# 29188  Beijing     2008
# 29189  Beijing     2008
# 29190  Beijing     2008
# 29191  Beijing     2008
# ...

# %%
oo.columns
# Out:
# Index([u'City', u'Edition', u'Sport', u'Discipline', u'Athlete', u'NOC',
#        u'Gender', u'Event', u'Event_gender', u'Medal'],
#       dtype='object')

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo.shape
# Out:
# (29216, 10)

# %%
oo.shape[0]
# Out:
# 29216

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # value counts

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
plt.plot(oo.Edition.value_counts(),'x')

# %%
oo.Gender.value_counts(ascending=False, dropna=False)
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %% [markdown]
# # sorting value

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
oo.sort_values(by=[ 'Edition', 'Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo[oo.Medal=='Gold']
# Out:
#           City  Edition          Sport       Discipline  \
# 0       Athens     1896       Aquatics         Swimming
# 3       Athens     1896       Aquatics         Swimming
# 6       Athens     1896       Aquatics         Swimming
# 9       Athens     1896       Aquatics         Swimming
# 13      Athens     1896      Athletics        Athletics
# 15      Athens     1896      Athletics        Athletics
# 18      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 24      Athens     1896      Athletics        Athletics
# 27      Athens     1896      Athletics        Athletics
# 29      Athens     1896      Athletics        Athletics
# 33      Athens     1896      Athletics        Athletics
# 36      Athens     1896      Athletics        Athletics
# 40      Athens     1896      Athletics        Athletics
# 43      Athens     1896      Athletics        Athletics
# 46      Athens     1896      Athletics        Athletics
# ...

# %%
oo[(oo.Gender=='Women') & (oo.Medal=='Gold')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %% [markdown]
# #string handling

# %%
oo[oo.Athlete.str.contains('GRIFFITH-JOYNER, Florence')]
# Out:
#               City  Edition      Sport Discipline                    Athlete  \
# 16817  Los Angeles     1984  Athletics  Athletics  GRIFFITH-JOYNER, Florence
# 18287        Seoul     1988  Athletics  Athletics  GRIFFITH-JOYNER, Florence
# 18305        Seoul     1988  Athletics  Athletics  GRIFFITH-JOYNER, Florence
# 18347        Seoul     1988  Athletics  Athletics  GRIFFITH-JOYNER, Florence
# 18374        Seoul     1988  Athletics  Athletics  GRIFFITH-JOYNER, Florence
#
#        NOC Gender         Event Event_gender   Medal
# 16817  USA  Women          200m            W  Silver
# 18287  USA  Women          100m            W    Gold
# 18305  USA  Women          200m            W    Gold
# 18347  USA  Women  4x100m relay            W    Gold
# 18374  USA  Women  4x400m relay            W  Silver

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
oo_badminton = oo[(oo.Sport == 'Badminton') & (oo.Gender == 'Men') & (oo.Medal == 'Gold')]
print(oo_badminton.sort_values(by='Athlete'))
print(oo_badminton.NOC.value_counts())
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
oo[(oo.Sport == 'Badminton') & (oo.Gender == 'Men') & (oo.Medal == 'Gold')].sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
oo_year = oo[(oo.Edition >=1984) & (oo.Edition <=2008)]
oo_year.NOC.value_counts()[:3]
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
oo_100m = oo[(oo.Event == '100m') & (oo.Gender == 'Men') & (oo.Medal == 'Gold')].sort_values(by='Edition', ascending=False)
oo_100m
# Out:
#                         City  Edition      Sport Discipline  \
# 27552                Beijing     2008  Athletics  Athletics
# 25539                 Athens     2004  Athletics  Athletics
# 23521                 Sydney     2000  Athletics  Athletics
# 21598                Atlanta     1996  Athletics  Athletics
# 19859              Barcelona     1992  Athletics  Athletics
# 18284                  Seoul     1988  Athletics  Athletics
# 16794            Los Angeles     1984  Athletics  Athletics
# 15374                 Moscow     1980  Athletics  Athletics
# 14069               Montreal     1976  Athletics  Athletics
# 12902                 Munich     1972  Athletics  Athletics
# 11865                 Mexico     1968  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# ...

# %%
type(oo_100m)
# Out:
# pandas.core.frame.DataFrame

# %%
oo_100m.NOC.value_counts()
# Out:
# USA    16
# GBR     3
# CAN     2
# RSA     1
# EUA     1
# URS     1
# JAM     1
# TRI     1
# Name: NOC, dtype: int64

# %%
fo = oo[oo.Edition == 1896]

# %%
fo.Sport.value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
fo.Sport.value_counts().plot(figsize=(12, 8), color='blue', kind='line');

# %%
fo.Sport.value_counts().plot(figsize=(12, 8), kind='bar');

# %%
fo.Sport.value_counts().plot(kind='pie', colormap='Pastel1');

# %%
plt.figure(figsize=(10,4))
sns.set(style='darkgrid')
sns.countplot( x='Medal', data=oo, hue='Gender')

# %%
oo_chn = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')]
sns.countplot(x='Gender', data=oo_chn)
print(oo_chn.Gender.value_counts())
# Out:
# Women    128
# Men       56
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Medal', data=oo_chn, hue='Gender', palette='bwr', order=['Gold', 'Silver', 'Bronze'])

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Edition', data=oo)

# %%
oo[(oo.Edition==2008)]['NOC'].value_counts()
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# NOR     22
# ROU     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# ISL     14
# KEN     14
# NZL     14
# KAZ     13
#       ...
# IRL      3
# IND      3
# AUT      3
# SIN      3
# EST      3
# LAT      3
# IRI      2
# DOM      2
# POR      2
# MAR      2
# TJK      2
# ALG      2
# COL      2
# KGZ      2
# MRI      1
# ECU      1
# TOG      1
# MDA      1
# RSA      1
# PAN      1
# TUN      1
# CHI      1
# MAS      1
# VEN      1
# AFG      1
# ISR      1
# VIE      1
# SUD      1
# EGY      1
# CMR      1
# Name: NOC, Length: 86, dtype: int64

# %%
lo = oo[(oo.Edition==2008)]['NOC'].value_counts()
lo
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# NOR     22
# ROU     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# ISL     14
# KEN     14
# NZL     14
# KAZ     13
#       ...
# IRL      3
# IND      3
# AUT      3
# SIN      3
# EST      3
# LAT      3
# IRI      2
# DOM      2
# POR      2
# MAR      2
# TJK      2
# ALG      2
# COL      2
# KGZ      2
# MRI      1
# ECU      1
# TOG      1
# MDA      1
# RSA      1
# PAN      1
# TUN      1
# CHI      1
# MAS      1
# VEN      1
# AFG      1
# ISR      1
# VIE      1
# SUD      1
# EGY      1
# CMR      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc = pd.read_csv(r'c:/Users/fanchang/Downloads/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country']!=noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index('Int Olympic Committee code', inplace=True)
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
noc['Medal_2008']=lo
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             Medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc['Medal_2008'].isnull()]
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# ALB                                                  Albania       AL
# ASA                                          American Samoa*       AS
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ARU                                                   Aruba*       AW
# BRN                                                  Bahrain       BH
# BAN                                               Bangladesh       BD
# BAR                                                 Barbados       BB
# BIZ                                                   Belize       BZ
# BER                                                 Bermuda*       BM
# BEN                                                    Benin       BJ
# ...

# %%
oo.groupby('Edition')

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896L,        City  Edition          Sport       Discipline  \
#   0    Athens     1896       Aquatics         Swimming
#   1    Athens     1896       Aquatics         Swimming
#   2    Athens     1896       Aquatics         Swimming
#   3    Athens     1896       Aquatics         Swimming
#   4    Athens     1896       Aquatics         Swimming
#   5    Athens     1896       Aquatics         Swimming
#   6    Athens     1896       Aquatics         Swimming
#   7    Athens     1896       Aquatics         Swimming
#   8    Athens     1896       Aquatics         Swimming
#   9    Athens     1896       Aquatics         Swimming
#   10   Athens     1896       Aquatics         Swimming
#   11   Athens     1896      Athletics        Athletics
#   12   Athens     1896      Athletics        Athletics
#   13   Athens     1896      Athletics        Athletics
#   14   Athens     1896      Athletics        Athletics
#   15   Athens     1896      Athletics        Athletics
# ...

# %%
for group_key, group_value in oo.groupby('Edition'):
    print group_key
    print group_value
# Out:
# 1896
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# 5    Athens     1896       Aquatics         Swimming
# 6    Athens     1896       Aquatics         Swimming
# 7    Athens     1896       Aquatics         Swimming
# 8    Athens     1896       Aquatics         Swimming
# 9    Athens     1896       Aquatics         Swimming
# 10   Athens     1896       Aquatics         Swimming
# 11   Athens     1896      Athletics        Athletics
# 12   Athens     1896      Athletics        Athletics
# 13   Athens     1896      Athletics        Athletics
# 14   Athens     1896      Athletics        Athletics
# 15   Athens     1896      Athletics        Athletics
# 16   Athens     1896      Athletics        Athletics
# ...

# %%
oo.groupby(['Edition', 'NOC', 'Medal']).agg({'Edition':'count'})
# Out:
#                     Edition
# Edition NOC Medal
# 1896    AUS Gold          2
#         AUT Bronze        2
#             Gold          2
#             Silver        1
#         DEN Bronze        3
#             Gold          1
#             Silver        2
#         FRA Bronze        2
#             Gold          5
#             Silver        4
#         GBR Bronze        2
#             Gold          2
#             Silver        3
#         GER Bronze        2
#             Gold         26
#             Silver        5
#         GRE Bronze       22
#             Gold         10
#             Silver       20
#         HUN Bronze        3
#             Gold          2
#             Silver        1
#         SUI Gold          1
#             Silver        2
#         USA Bronze        2
#             Gold         11
#             Silver        7
#         ZZX Bronze        2
#             Gold          2
#             Silver        2
# ...                     ...
# ...

# %%
carl = oo.loc[oo.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min', 'max', 'count']})
carl
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
numofmedal = oo.groupby(['Edition']).size()
print numofmedal
plt.plot(numofmedal)
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby(['NOC']).agg({'Edition':['min', 'max','count']})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-223-05bd14a80820> in <module>()
# ----> 1 oo.groupby(['NOC']).agg({'Edition':['min', 'max','count']}).size()
#
# TypeError: 'numpy.int32' object is not callable

# %%
oo.groupby(['Edition']).agg({'Medal':'count'}).plot(kind='bar', figsize=(12, 5))

# %%
mw = oo[(oo.Edition==2008) & ((oo.Event == '100m') | (oo.Event=='200m'))]
mw
# Out:
#           City  Edition      Sport Discipline                   Athlete  NOC  \
# 27551  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27552  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27553  Beijing     2008  Athletics  Athletics         THOMPSON, Richard  TRI
# 27554  Beijing     2008  Athletics  Athletics        FRASER, Shelly-ann  JAM
# 27555  Beijing     2008  Athletics  Athletics          SIMPSON, Sherone  JAM
# 27556  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27569  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27570  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27571  Beijing     2008  Athletics  Athletics           CRAWFORD, Shawn  USA
# 27572  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27573  Beijing     2008  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
# ...

# %%
g = mw.groupby(['NOC', 'Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df = g.unstack(['Discipline', 'Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
df.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
usgold = oo[(oo.NOC == 'USA') & (oo.Medal == 'Gold')].groupby(['Edition','Gender']).size()
plt.figure(figsize=(12, 5))
usgold.unstack('Gender',fill_value=0).plot(kind='bar', figsize=(12, 6))
# sns.countplot(x='Edition', data=usgold, hue='Gender')

# %%
newoo = oo.groupby(['Athlete','Medal']).size()
# sns.figure(figsize=(12,6))
newoo.unstack('Medal', fill_value=0).sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']].head().plot(kind='bar', figsize=(9,6))

# %%
df =oo[oo.Edition==2008].groupby(['NOC','Medal']).size().unstack('Medal',fill_value=0)[['Gold', 'Silver', 'Bronze']]
df = df.transpose()
print df.head()
plt.figure(figsize=(25, 3))
sns.heatmap(df, cmap="YlGnBu")
# Out:
# NOC     AFG  ALG  ARG  ARM  AUS  AUT  AZE  BAH  BEL  BLR ...   TPE  TRI  TUN  \
# Medal                                                    ...
# Gold      0    0   20    0   31    0    1    0    1    8 ...     0    0    1
# Silver    0    1    0    0   42    1    2    4    4    5 ...     0    5    0
# Bronze    1    1   31    6   76    2    4    1    0   17 ...     4    0    0
#
# NOC     TUR  UKR  USA  UZB  VEN  VIE  ZIM
# Medal
# Gold      1   10  125    1    0    0    1
# Silver    4    5  109    2    0    1    3
# Bronze    3   16   81    3    1    0    0
#
# [3 rows x 86 columns]

# %%
df.shape
# Out:
# (3, 86)

# %%
us = oo[oo.NOC=='USA']
us.head()
# Out:
#       City  Edition      Sport Discipline         Athlete  NOC Gender  \
# 11  Athens     1896  Athletics  Athletics   LANE, Francis  USA    Men
# 13  Athens     1896  Athletics  Athletics   BURKE, Thomas  USA    Men
# 15  Athens     1896  Athletics  Athletics  CURTIS, Thomas  USA    Men
# 19  Athens     1896  Athletics  Athletics   BLAKE, Arthur  USA    Men
# 21  Athens     1896  Athletics  Athletics   BURKE, Thomas  USA    Men
#
#            Event Event_gender   Medal
# 11          100m            M  Bronze
# 13          100m            M    Gold
# 15  110m hurdles            M    Gold
# 19         1500m            M  Silver
# 21          400m            M    Gold

# %%
usmedal = us.groupby(['Edition', 'Athlete', 'Medal']).size().unstack('Medal', fill_value=0)
usmedal.reset_index(inplace=True)
usmedal.head()
# Out:
# Medal  Edition          Athlete  Bronze  Gold  Silver
# 0         1896    BLAKE, Arthur       0     0       1
# 1         1896    BURKE, Thomas       0     2       0
# 2         1896    CLARK, Ellery       0     2       0
# 3         1896  CONNOLLY, James       1     1       1
# 4         1896   CURTIS, Thomas       0     1       0

# %%
usmedal['Total']=usmedal['Bronze']+usmedal.Gold + usmedal.Silver
usmedal.head()
# Out:
# Medal  Edition          Athlete  Bronze  Gold  Silver  Total
# 0         1896    BLAKE, Arthur       0     0       1      1
# 1         1896    BURKE, Thomas       0     2       0      2
# 2         1896    CLARK, Ellery       0     2       0      2
# 3         1896  CONNOLLY, James       1     1       1      3
# 4         1896   CURTIS, Thomas       0     1       0      1

# %%
tu =[value.sort_values(by='Total', ascending=False)[:1] for group, value in usmedal.groupby('Edition')]
df = pd.DataFrame()
for row in medallist:
    df = df.append(tu)

newdf=df[['Edition', 'Athlete', 'Total']]
plt.plot(newdf.Edition, newdf.Total, 'o')

# %%
newdf.head()
# Out:
# Medal  Edition                Athlete  Total
# 5         1896        GARRETT, Robert      4
# 14        1900         BAXTER, Irving      5
# 153       1904           HEIDA, Anton      6
# 363       1908       SHERIDAN, Martin      3
# 421       1912  OSBURN, Carl Townsend      4
