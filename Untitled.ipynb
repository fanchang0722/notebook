# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pylab as plt
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import pandas.util.testing as tm; tm.N = 3
def unpivot(frame):
    N, K = frame.shape
    data = {'value' : frame.values.ravel('F'),
            'variable' : np.asarray(frame.columns).repeat(N),
            'date' : np.tile(np.asarray(frame.index), K)}
    return pd.DataFrame(data, columns=['date', 'variable', 'value'])
df = unpivot(tm.makeTimeDataFrame())
df
# Out:
#          date variable     value
# 0  2000-01-03        A  0.596679
# 1  2000-01-04        A -0.510429
# 2  2000-01-05        A -0.400427
# 3  2000-01-03        B -0.354354
# 4  2000-01-04        B  0.594924
# 5  2000-01-05        B -0.524014
# 6  2000-01-03        C  0.893778
# 7  2000-01-04        C  1.131739
# 8  2000-01-05        C  0.354863
# 9  2000-01-03        D  2.090738
# 10 2000-01-04        D  0.082293
# 11 2000-01-05        D  1.073306

# %%
df.pivot(index='date', columns='variable', values='value')
# Out:
# variable           A         B         C         D
# date
# 2000-01-03  0.596679 -0.354354  0.893778  2.090738
# 2000-01-04 -0.510429  0.594924  1.131739  0.082293
# 2000-01-05 -0.400427 -0.524014  0.354863  1.073306

# %%
sharesIndexDataDF=pd.read_csv('stock_index_prices.csv');
sharesIndexDataDF
# Out:
#    TradingDate PriceType   Nasdaq  S&P 500  Russell 2000
# 0   2014/02/21      open  4282.17  1841.07       1166.25
# 1   2014/02/21     close  4263.41  1836.25       1164.63
# 2   2014/02/21      high  4284.85  1846.13       1168.43
# 3   2014/02/24      open  4273.32  1836.78       1166.74
# 4   2014/02/24     close  4292.97  1847.61       1174.55
# 5   2014/02/24      high  4311.13  1858.71       1180.29
# 6   2014/02/25      open  4298.48  1847.66       1176.00
# 7   2014/02/25     close  4287.59  1845.12       1173.95
# 8   2014/02/25      high  4307.51  1852.91       1179.43
# 9   2014/02/26      open  4300.45  1845.79       1176.11
# 10  2014/02/26     close  4292.06  1845.16       1181.72
# 11  2014/02/26      high  4316.82  1852.65       1188.06
# 12  2014/02/27      open  4291.47  1844.90       1179.28
# 13  2014/02/27     close  4318.93  1854.29       1187.94
# 14  2014/02/27      high  4322.46  1854.53       1187.94
# ...

# %%
sharesIndexDataDF.pivot(index='TradingDate', columns='PriceType', values='Nasdaq')
# Out:
# PriceType      close     high     open
# TradingDate
# 2014/02/21   4263.41  4284.85  4282.17
# 2014/02/24   4292.97  4311.13  4273.32
# 2014/02/25   4287.59  4307.51  4298.48
# 2014/02/26   4292.06  4316.82  4300.45
# 2014/02/27   4318.93  4322.46  4291.47
# 2014/02/28   4308.12  4342.59  4323.52

# %%
sharesIndexDF=sharesIndexDataDF.set_index(['TradingDate','PriceType'])
sharesIndexDF
# Out:
#                         Nasdaq  S&P 500  Russell 2000
# TradingDate PriceType
# 2014/02/21  open       4282.17  1841.07       1166.25
#             close      4263.41  1836.25       1164.63
#             high       4284.85  1846.13       1168.43
# 2014/02/24  open       4273.32  1836.78       1166.74
#             close      4292.97  1847.61       1174.55
#             high       4311.13  1858.71       1180.29
# 2014/02/25  open       4298.48  1847.66       1176.00
#             close      4287.59  1845.12       1173.95
#             high       4307.51  1852.91       1179.43
# 2014/02/26  open       4300.45  1845.79       1176.11
#             close      4292.06  1845.16       1181.72
#             high       4316.82  1852.65       1188.06
# 2014/02/27  open       4291.47  1844.90       1179.28
#             close      4318.93  1854.29       1187.94
#             high       4322.46  1854.53       1187.94
# 2014/02/28  open       4323.52  1855.12       1189.19
# ...

# %%
SFR_DF=pd.read_csv(r'/Users/fanchang/Downloads/measures/Camera_SFR_Pos_6-15-2016.csv');
SFR_DF.head(5)
# Out:
#      Test station            FF_SID Test Result     Test Start       Test End  \
# 0  Camera_SFR_Pos  BSJ1P0M116190305        PASS  5/13/16 18:11  5/13/16 18:11
# 1  Camera_SFR_Pos  BSJ1P0M116190305        PASS  5/13/16 18:11  5/13/16 18:11
# 2  Camera_SFR_Pos  BSJ1P0M216190428        PASS  5/17/16 16:01  5/17/16 16:02
# 3  Camera_SFR_Pos  BSJ1P0M216190428        PASS  5/17/16 16:01  5/17/16 16:02
# 4  Camera_SFR_Pos  BSJ1P0M216190428        PASS  5/17/16 16:01  5/17/16 16:02
#
#     Function Result        Metrics   Value       Validator
# 0  Camera_IQ   PASS  SFR_NQ4_50F_V  0.3956  0.21 <= x <= 1
# 1  Camera_IQ   PASS        TV_Dist -3.4870          #NAME?
# 2  Camera_IQ   PASS  SFR_NQ4_50F_V  0.4731  0.21 <= x <= 1
# 3  Camera_IQ   PASS        TV_Dist -3.6740          #NAME?
# 4  Camera_IQ   PASS  SFR_NQ4_70F_V  0.5232   0.2 <= x <= 1

# %%
SFR_NQ4_50F_V=SFR_DF[SFR_DF['Metrics']=='SFR_NQ4_50F_V']
SFR_Test=SFR_NQ4_50F_V.head(50)
SFR_Test.pivot(index='Test Start', columns='FF_SID', values='Value')
# Out:
# FF_SID         BSJ1P0M116190301  BSJ1P0M116190303  BSJ1P0M116190305  \
# Test Start
# 5/11/16 17:10               NaN               NaN               NaN
# 5/11/16 17:19               NaN               NaN               NaN
# 5/11/16 18:06               NaN               NaN               NaN
# 5/11/16 18:09               NaN               NaN               NaN
# 5/11/16 20:42               NaN               NaN               NaN
# 5/12/16 14:27               NaN               NaN               NaN
# 5/12/16 17:06               NaN               NaN               NaN
# 5/13/16 10:03               NaN               NaN               NaN
# 5/13/16 18:11               NaN               NaN            0.3956
# 5/13/16 18:14               NaN            0.4783               NaN
# 5/13/16 18:15               NaN            0.5179               NaN
# 5/13/16 9:47                NaN               NaN               NaN
# 5/14/16 10:40               NaN               NaN               NaN
# ...
