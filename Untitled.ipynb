# %%
# %pylab inline
import matplotlib.pylab as plt
import numpy as np
import scipy as sp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
RI_UL=np.array([0.157,0.165,0.184,0.205,0.23,0.259,0.291,0.324,0.357,0.392,0.43,0.471,0.513,0.556,0.596,
                0.634,0.663,0.688,0.703,0.714,0.717,0.715,0.707,0.691,0.667,0.636,0.599,0.557,0.514,
                0.472,0.429,0.391,0.355,0.322,0.289,0.258,0.229,0.204,0.184,0.165,0.154])

# %%
plt.figure(figsize=(12,9))
plt.plot(RI_UL[:], '-bo', lw=2)
plt.grid()
