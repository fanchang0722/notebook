# %%
# %pylab inline
import numpy as np
import matplotlib as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['byte', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
x=arange(10)
plot(x)

# %%
fid=open('/Users/fanchang/Google Drive/Phoenix/raw_image/60cm.raw','rb')
data=fid.read()
fid.close()
img=zeros(len(data)/2)
for index in range(len(data)/2):
    img[index]=ord(data[2*index:2*index+1])
img2=np.reshape(img,(2448,3264))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7dd5c453c0b2> in <module>()
#       2 data=fid.read()
#       3 fid.close()
# ----> 4 img=zeros(len(data)/2)
#       5 for index in range(len(data)/2):
#       6     img[index]=ord(data[2*index:2*index+1])
#
# NameError: name 'zeros' is not defined

# %%
plt.imshow(img2)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
plt.imshow(img2)

# %%
unpack('h','01')
# Out:
# (12592,)

# %%
type(ord(data[0:1]))
# Out:
# int

# %%
type(data[0])
# Out:
# str
