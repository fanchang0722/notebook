# %%
import os
import matplotlib.pylab as plt
import pandas as pd
import numpy as np

# %%
df= pd.read_excel(r'c:/Users/fanchang/Desktop/rear_geo.xlsx')
df.describe()
X = np.array(df['Loc_x'])
Y = np.array(df['Loc_y'])
Z = np.array(df['Brightness'])
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-67412f3c1dcf> in <module>()
#       5 Z = np.array(df['Brightness'])
#       6 plt.figure()
# ----> 7 CS = plt.contour(X, Y, Z)
#       8 plt.clabel(CS, inline=1, fontsize=10)
#       9 plt.title('Simplest default with labels')
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\pyplot.pyc in contour(*args, **kwargs)
#    2916                       mplDeprecation)
#    2917     try:
# -> 2918         ret = ax.contour(*args, **kwargs)
#    2919     finally:
#    2920         ax._hold = washold
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\axes\_axes.pyc in contour(self, *args, **kwargs)
#    6278             self.cla()
#    6279         kwargs['filled'] = False
# -> 6280         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6281         self.autoscale_view()
#    6282         return contours
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\contour.pyc in __init__(self, ax, *args, **kwargs)
#     888         self._transform = kwargs.pop('transform', None)
#     889
# --> 890         kwargs = self._process_args(*args, **kwargs)
#     891         self._process_levels()
#     892
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\contour.pyc in _process_args(self, *args, **kwargs)
#    1474                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1475
# -> 1476             x, y, z = self._contour_args(args, kwargs)
#    1477
#    1478             _mask = ma.getmask(z)
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\contour.pyc in _contour_args(self, args, kwargs)
#    1532             args = args[1:]
#    1533         elif Nargs <= 4:
# -> 1534             x, y, z = self._check_xyz(args[:3], kwargs)
#    1535             args = args[3:]
#    1536         else:
#
# c:\python_27_amd64\files\lib\site-packages\matplotlib\contour.pyc in _check_xyz(self, args, kwargs)
#    1566
#    1567         if z.ndim != 2:
# -> 1568             raise TypeError("Input z must be a 2D array.")
#    1569         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1570             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input z must be a 2D array.

# %%
df.columns
# Out:
# Index([u'Loc_x', u'Loc_y', u'Brightness 照度', u'CCT 色温'], dtype='object')

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = mlab.bivariate_normal(X, Y, 1.0, 1.0, 0.0, 0.0)
Z2 = mlab.bivariate_normal(X, Y, 1.5, 0.5, 1, 1)
# difference of Gaussians
Z = 10.0 * (Z2 - Z1)


# Create a simple contour plot with labels using default colors.  The
# inline argument to clabel will control whether the labels are draw
# over the line segments of the contour, removing the lines beneath
# the label
plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.title('Simplest default with labels')
# Out:
# c:\python_27_amd64\files\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#
# c:\python_27_amd64\files\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: The bivariate_normal function was deprecated in version 2.2.
#   from ipykernel import kernelapp as app
# Text(0.5,1,'Simplest default with labels')

# %%
np.shape(Z)
# Out:
# (160L, 240L)

# %%
np.shape(X)
# Out:
# (160L, 240L)
