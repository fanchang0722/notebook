# %%
import os
import sys
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv(r'/Users/fanchang/Desktop/B1C1EVT/test_result/B1/B1_Combo_all_20180421105449.csv')
df.columns
# Out:
# Index([u'station_id', u'device_config', u'dut_id', u'china_timestamp',
#        u'china_date', u'china_time', u'DUT_Status', u'phases.name',
#        u'parameter', u'status', u'lsl', u'numeric_val', u'usl', u'mode'],
#       dtype='object')

# %%
dfDate = df['china_date'].value_counts().keys()
print(dfDate)
# Out:
# Index([u'2018-04-19 ', u'2018-04-20 ', u'2018-04-21 '], dtype='object')

# %%
dfPass = df[df['DUT_Status'] == 'PASS']
dfPass.head(5)
# Out:
#     station_id device_config     dut_id      china_timestamp   china_date  \
# 0  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 1  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 2  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 3  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 4  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
#
#   china_time DUT_Status          phases.name           parameter status   lsl  \
# 0   13:07:57       PASS        start_capture                 NaN    NaN   NaN
# 1   13:07:57       PASS      dual_camera_cal                 NaN    NaN   NaN
# 2   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TR_H   PASS  0.39
# 3   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TL_V   PASS  0.39
# 4   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_80IH_TR_V   PASS  0.19
#
#    numeric_val  usl        mode
# ...

# %%
for index in dfDate:
    print(index)
    pd.dateframe(eval('a'))
#     newdfName =  'pass_' + str(index)
#     print(type(newdfName))
#     pd.dateframe(
#     newdfName = pd.dateframe(newdfName)
#     print(type(newdfName))
#     newdfName=dfPass[dfPass['china_date'] == index]
#     print newdfName.head(3)
# Out:
# 2018-04-19
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-f3b49a47cb17> in <module>()
#       1 for index in dfDate:
#       2     print(index)
# ----> 3     pd.dateframe(eval('a'))
#       4 #     newdfName =  'pass_' + str(index)
#       5 #     print(type(newdfName))
#
# AttributeError: 'module' object has no attribute 'dateframe'

# %%
dfFail = df[df['DUT_Status'] == 'FAIL']
dfFail.head(5)
# Out:
#      station_id device_config     dut_id      china_timestamp   china_date  \
# 225  G01COMBO01         Mini1  84DX005C2  2018-04-19 14:43:21  2018-04-19
# 226  G01COMBO01         Mini1  84DX005C2  2018-04-19 14:43:21  2018-04-19
# 227  G01COMBO01         Mini1  84DX005C2  2018-04-19 14:43:21  2018-04-19
# 228  G01COMBO01         Mini1  84DX005C2  2018-04-19 14:43:21  2018-04-19
# 229  G01COMBO01         Mini1  84DX005C2  2018-04-19 14:43:21  2018-04-19
#
#     china_time DUT_Status          phases.name            parameter status  \
# 225   14:43:21       FAIL        start_capture                  NaN    NaN
# 226   14:43:21       FAIL  NFOV_SFR_Test_Macro  SFR_110lp_60IH_TL_H   PASS
# 227   14:43:21       FAIL  NFOV_SFR_Test_Macro  SFR_110lp_60IH_BR_V   PASS
# 228   14:43:21       FAIL  NFOV_SFR_Test_Macro  SFR_110lp_30IH_BL_V   PASS
# 229   14:43:21       FAIL  NFOV_SFR_Test_Macro  SFR_110lp_60IH_TR_V   PASS
#
#       lsl  numeric_val  usl        mode
# ...

# %%
df['station_id'].value_counts()
# Out:
# G01COMBO03     15581
# G01COMBO01     12468
# G01COMBO04     11370
# G01COMBO02      9775
# G01COMBO204     9361
# G01COMBO205     8714
# G01COMBO203     6980
# G01COMBO201     5759
# G01COMBO202     3490
# Name: station_id, dtype: int64

# %%
df['china_date'].value_counts().keys()
# Out:
# Index([u'2018-04-19 ', u'2018-04-20 ', u'2018-04-21 '], dtype='object')

# %%
newdf = df.groupby('china_date')['station_id'].value_counts()

# %%
df.head(5)
# Out:
#     station_id device_config     dut_id      china_timestamp   china_date  \
# 0  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 1  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 2  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 3  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 4  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
#
#   china_time DUT_Status          phases.name           parameter status   lsl  \
# 0   13:07:57       PASS        start_capture                 NaN    NaN   NaN
# 1   13:07:57       PASS      dual_camera_cal                 NaN    NaN   NaN
# 2   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TR_H   PASS  0.39
# 3   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TL_V   PASS  0.39
# 4   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_80IH_TR_V   PASS  0.19
#
#    numeric_val  usl        mode
# ...

# %%
df20180419 = df[df['china_date'] == '2018-04-19']
df20180419.head(5)
# Out:
#     station_id device_config     dut_id      china_timestamp  china_date  \
# 0  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 1  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 2  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 3  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 4  G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
#
#   china_time DUT_Status          phases.name           parameter status   lsl  \
# 0   13:07:57       PASS        start_capture                 NaN    NaN   NaN
# 1   13:07:57       PASS      dual_camera_cal                 NaN    NaN   NaN
# 2   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TR_H   PASS  0.39
# 3   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_30IH_TL_V   PASS  0.39
# 4   13:07:57       PASS  Rear_SFR_Test_Macro  SFR_55lp_80IH_TR_V   PASS  0.19
#
#    numeric_val  usl        mode
# ...

# %%
df[df['china_date'] == '2018-04-19']
# Out:
#         station_id device_config     dut_id      china_timestamp  china_date  \
# 0      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 1      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 2      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 3      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 4      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 5      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 6      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 7      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 8      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 9      G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# 10     G01COMBO205         Mini3  84GX005HP  2018-04-19 13:07:57  2018-04-19
# ...

# %%
eval('pd.dateframe(a)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-bd5d229409a5> in <module>()
# ----> 1 eval('pd.dateframe(a)')
#
# <string> in <module>()
#
# AttributeError: 'module' object has no attribute 'dateframe'

# %%
df2=pd.dataframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-4f21ca674de8> in <module>()
# ----> 1 df2=pd.dataframe()
#
# AttributeError: 'module' object has no attribute 'dataframe'

# %%
a=pd.DataFrame()

# %%
eval('b'+str(1))=pd.DateFrame()
# Out:
#   File "<ipython-input-93-ad93ac088af5>", line 1
#     eval('b'+str(1))=pd.DateFrame()
# SyntaxError: can't assign to function call

# %%
eval('b'+str(1)=pd.DataFrame())
# Out:
#   File "<ipython-input-96-1aec9e38a210>", line 1
#     eval('b'+str(1)=pd.DataFrame())
# SyntaxError: keyword can't be an expression

# %%
logicalTrue =
