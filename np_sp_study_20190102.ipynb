# %%
list('abc')
# Out:
# ['a', 'b', 'c']

# %%
def variable_args(*args, **kwargs):
    print 'args is', args
    print 'kwargs is', kwargs

# %%
variable_args('one', 'two', x=1, y=2, z=3)
# Out:
# args is ('one', 'two')
# kwargs is {'y': 2, 'x': 1, 'z': 3}

# %%
def funcname(params):
    """Concise one-line sentence describing the function.
    
    Extended summary which can contain multiple paragraphs.
    
    """
    # function body
    pass

# %%
funcname?

# %%
# %run test.py
# Out:
# Hello
# how
# are
# you?

# %%
message
# Out:
# 'Hello how are you?'

# %%
import os

# %%
os
# Out:
# <module 'os' from 'c:\python_27_amd64\files\lib\os.pyc'>

# %%
os.listdir('.')
# Out:
# ['.DS_Store',
#  '.git',
#  '.ipynb_checkpoints',
#  'A50_data_analysis.ipynb',
#  'A50_EVT_Data_Analysis.ipynb',
#  'A65_P2_Camera_SFR.ipynb',
#  'Android_camera_decode.ipynb',
#  'B1C1_daily_analysis.ipynb',
#  'B1C1_test_20181117.csv',
#  'B1_front_NFOV_list',
#  'B1_front_wide_SFR_list',
#  'B1_proto_batch.ipynb',
#  'B1_proto_front_NFOV_10m_SFR.csv',
#  'B1_proto_front_NFOV_10m_SFR.jmp',
#  'B1_proto_front_NFOV_10m_SFR.xlsx',
#  'B1_proto_front_NFOV_5100_blemish.csv',
#  'B1_proto_front_NFOV_5100_OC.csv',
#  'B1_proto_front_NFOV_5100_RI.csv',
#  'B1_proto_front_NFOV_AWB.csv',
#  'B1_proto_front_NFOV_AWB_list',
#  'B1_proto_front_NFOV_list',
#  'B1_proto_front_NFOV_SFR_list',
#  'B1_proto_front_WFOV_5100_blemish.csv',
#  'B1_proto_front_WFOV_5100_OC.csv',
#  'B1_proto_front_WFOV_5100_RI.csv',
#  'B1_proto_front_WFOV_65cm_SFR.csv',
#  'B1_proto_front_WFOV_65cm_SFR.jmp',
#  'B1_proto_front_WFOV_65cm_SFR.xlsx',
#  'B1_proto_NFOV_light_5000_RI_list',
#  'B1_proto_NFOV_light_5100_blemish_list',
#  'B1_proto_NFOV_light_5100_OC_list',
#  'B1_proto_rear_10m_SFR.csv',
#  'B1_proto_rear_10m_SFR.jmp',
#  'B1_proto_rear_10m_SFR.xlsx',
#  'B1_proto_rear_blemish.csv',
#  'B1_proto_rear_blemish_list',
#  'B1_proto_rear_RI.csv',
#  'B1_proto_rear_RI_list',
#  'B1_proto_WFOV_light_5000_RI_list',
#  'B1_proto_WFOV_light_5100_blemish_list',
#  'B1_proto_WFOV_light_5100_OC_list',
#  'B1_rear_10m_SFR_list',
#  'BottomLeft_SFR_Ny2_H_1_FAIL.csv',
#  'BottomLeft_SFR_Ny2_H_1_nan.csv',
#  'BottomLeft_SFR_Ny2_H_1_PASS.csv',
#  'BottomLeft_SFR_Ny2_H_1_UNSET.csv',
#  'BottomLeft_SFR_Ny2_H_2_FAIL.csv',
#  'BottomLeft_SFR_Ny2_H_2_nan.csv',
#  'BottomLeft_SFR_Ny2_H_2_PASS.csv',
#  'BottomLeft_SFR_Ny2_H_2_UNSET.csv',
#  'BottomLeft_SFR_Ny2_H_FAIL.csv',
#  'BottomLeft_SFR_Ny2_H_nan.csv',
#  'BottomLeft_SFR_Ny2_H_PASS.csv',
#  'BottomLeft_SFR_Ny2_H_UNSET.csv',
#  'BottomLeft_SFR_Ny2_V_1_FAIL.csv',
#  'BottomLeft_SFR_Ny2_V_1_nan.csv',
#  'BottomLeft_SFR_Ny2_V_1_PASS.csv',
#  'BottomLeft_SFR_Ny2_V_1_UNSET.csv',
#  'BottomLeft_SFR_Ny2_V_2_FAIL.csv',
#  'BottomLeft_SFR_Ny2_V_2_nan.csv',
#  'BottomLeft_SFR_Ny2_V_2_PASS.csv',
#  'BottomLeft_SFR_Ny2_V_2_UNSET.csv',
#  'BottomLeft_SFR_Ny2_V_FAIL.csv',
#  'BottomLeft_SFR_Ny2_V_nan.csv',
#  'BottomLeft_SFR_Ny2_V_PASS.csv',
#  'BottomLeft_SFR_Ny2_V_UNSET.csv',
#  'BottomLeft_SFR_Ny4_H_1_FAIL.csv',
#  'BottomLeft_SFR_Ny4_H_1_nan.csv',
#  'BottomLeft_SFR_Ny4_H_1_PASS.csv',
#  'BottomLeft_SFR_Ny4_H_1_UNSET.csv',
#  'BottomLeft_SFR_Ny4_H_2_FAIL.csv',
#  'BottomLeft_SFR_Ny4_H_2_nan.csv',
#  'BottomLeft_SFR_Ny4_H_2_PASS.csv',
#  'BottomLeft_SFR_Ny4_H_2_UNSET.csv',
#  'BottomLeft_SFR_Ny4_H_FAIL.csv',
#  'BottomLeft_SFR_Ny4_H_nan.csv',
#  'BottomLeft_SFR_Ny4_H_PASS.csv',
#  'BottomLeft_SFR_Ny4_H_UNSET.csv',
#  'BottomLeft_SFR_Ny4_V_1_FAIL.csv',
#  'BottomLeft_SFR_Ny4_V_1_nan.csv',
#  'BottomLeft_SFR_Ny4_V_1_PASS.csv',
#  'BottomLeft_SFR_Ny4_V_1_UNSET.csv',
#  'BottomLeft_SFR_Ny4_V_2_FAIL.csv',
#  'BottomLeft_SFR_Ny4_V_2_nan.csv',
#  'BottomLeft_SFR_Ny4_V_2_PASS.csv',
#  'BottomLeft_SFR_Ny4_V_2_UNSET.csv',
#  'BottomLeft_SFR_Ny4_V_FAIL.csv',
#  'BottomLeft_SFR_Ny4_V_nan.csv',
#  'BottomLeft_SFR_Ny4_V_PASS.csv',
#  'BottomLeft_SFR_Ny4_V_UNSET.csv',
#  'BottomRight_SFR_Ny2_H_1_FAIL.csv',
#  'BottomRight_SFR_Ny2_H_1_nan.csv',
#  'BottomRight_SFR_Ny2_H_1_PASS.csv',
#  'BottomRight_SFR_Ny2_H_1_UNSET.csv',
#  'BottomRight_SFR_Ny2_H_2_FAIL.csv',
#  'BottomRight_SFR_Ny2_H_2_nan.csv',
#  'BottomRight_SFR_Ny2_H_2_PASS.csv',
#  'BottomRight_SFR_Ny2_H_2_UNSET.csv',
#  'BottomRight_SFR_Ny2_H_FAIL.csv',
#  'BottomRight_SFR_Ny2_H_nan.csv',
#  'BottomRight_SFR_Ny2_H_PASS.csv',
#  'BottomRight_SFR_Ny2_H_UNSET.csv',
#  'BottomRight_SFR_Ny2_V_1_FAIL.csv',
#  'BottomRight_SFR_Ny2_V_1_nan.csv',
#  'BottomRight_SFR_Ny2_V_1_PASS.csv',
#  'BottomRight_SFR_Ny2_V_1_UNSET.csv',
#  'BottomRight_SFR_Ny2_V_2_FAIL.csv',
#  'BottomRight_SFR_Ny2_V_2_nan.csv',
#  'BottomRight_SFR_Ny2_V_2_PASS.csv',
#  'BottomRight_SFR_Ny2_V_2_UNSET.csv',
#  'BottomRight_SFR_Ny2_V_FAIL.csv',
#  'BottomRight_SFR_Ny2_V_nan.csv',
#  'BottomRight_SFR_Ny2_V_PASS.csv',
#  'BottomRight_SFR_Ny2_V_UNSET.csv',
#  'BottomRight_SFR_Ny4_H_1_FAIL.csv',
#  'BottomRight_SFR_Ny4_H_1_nan.csv',
#  'BottomRight_SFR_Ny4_H_1_PASS.csv',
#  'BottomRight_SFR_Ny4_H_1_UNSET.csv',
#  'BottomRight_SFR_Ny4_H_2_FAIL.csv',
#  'BottomRight_SFR_Ny4_H_2_nan.csv',
#  'BottomRight_SFR_Ny4_H_2_PASS.csv',
#  'BottomRight_SFR_Ny4_H_2_UNSET.csv',
#  'BottomRight_SFR_Ny4_H_FAIL.csv',
#  'BottomRight_SFR_Ny4_H_nan.csv',
#  'BottomRight_SFR_Ny4_H_PASS.csv',
#  'BottomRight_SFR_Ny4_H_UNSET.csv',
#  'BottomRight_SFR_Ny4_V_1_FAIL.csv',
#  'BottomRight_SFR_Ny4_V_1_nan.csv',
#  'BottomRight_SFR_Ny4_V_1_PASS.csv',
#  'BottomRight_SFR_Ny4_V_1_UNSET.csv',
#  'BottomRight_SFR_Ny4_V_2_FAIL.csv',
#  'BottomRight_SFR_Ny4_V_2_nan.csv',
#  'BottomRight_SFR_Ny4_V_2_PASS.csv',
#  'BottomRight_SFR_Ny4_V_2_UNSET.csv',
#  'BottomRight_SFR_Ny4_V_FAIL.csv',
#  'BottomRight_SFR_Ny4_V_nan.csv',
#  'BottomRight_SFR_Ny4_V_PASS.csv',
#  'BottomRight_SFR_Ny4_V_UNSET.csv',
#  'build_from_scratch.ipynb',
#  'C2F2_processing.ipynb',
#  'Center_SFR_Ny2_H_1_FAIL.csv',
#  'Center_SFR_Ny2_H_1_nan.csv',
#  'Center_SFR_Ny2_H_1_PASS.csv',
#  'Center_SFR_Ny2_H_1_UNSET.csv',
#  'Center_SFR_Ny2_H_2_FAIL.csv',
#  'Center_SFR_Ny2_H_2_nan.csv',
#  'Center_SFR_Ny2_H_2_PASS.csv',
#  'Center_SFR_Ny2_H_2_UNSET.csv',
#  'Center_SFR_Ny2_H_FAIL.csv',
#  'Center_SFR_Ny2_H_nan.csv',
#  'Center_SFR_Ny2_H_PASS.csv',
#  'Center_SFR_Ny2_H_UNSET.csv',
#  'Center_SFR_Ny2_V_1_FAIL.csv',
#  'Center_SFR_Ny2_V_1_nan.csv',
#  'Center_SFR_Ny2_V_1_PASS.csv',
#  'Center_SFR_Ny2_V_1_UNSET.csv',
#  'Center_SFR_Ny2_V_2_FAIL.csv',
#  'Center_SFR_Ny2_V_2_nan.csv',
#  'Center_SFR_Ny2_V_2_PASS.csv',
#  'Center_SFR_Ny2_V_2_UNSET.csv',
#  'Center_SFR_Ny2_V_FAIL.csv',
#  'Center_SFR_Ny2_V_nan.csv',
#  'Center_SFR_Ny2_V_PASS.csv',
#  'Center_SFR_Ny2_V_UNSET.csv',
#  'Center_SFR_Ny4_H_1_FAIL.csv',
#  'Center_SFR_Ny4_H_1_nan.csv',
#  'Center_SFR_Ny4_H_1_PASS.csv',
#  'Center_SFR_Ny4_H_1_UNSET.csv',
#  'Center_SFR_Ny4_H_2_FAIL.csv',
#  'Center_SFR_Ny4_H_2_nan.csv',
#  'Center_SFR_Ny4_H_2_PASS.csv',
#  'Center_SFR_Ny4_H_2_UNSET.csv',
#  'Center_SFR_Ny4_H_FAIL.csv',
#  'Center_SFR_Ny4_H_nan.csv',
#  'Center_SFR_Ny4_H_PASS.csv',
#  'Center_SFR_Ny4_H_UNSET.csv',
#  'Center_SFR_Ny4_V_1_FAIL.csv',
#  'Center_SFR_Ny4_V_1_nan.csv',
#  'Center_SFR_Ny4_V_1_PASS.csv',
#  'Center_SFR_Ny4_V_1_UNSET.csv',
#  'Center_SFR_Ny4_V_2_FAIL.csv',
#  'Center_SFR_Ny4_V_2_nan.csv',
#  'Center_SFR_Ny4_V_2_PASS.csv',
#  'Center_SFR_Ny4_V_2_UNSET.csv',
#  'Center_SFR_Ny4_V_FAIL.csv',
#  'Center_SFR_Ny4_V_nan.csv',
#  'Center_SFR_Ny4_V_PASS.csv',
#  'Center_SFR_Ny4_V_UNSET.csv',
#  'class_study_20180213.ipynb',
#  'custom_widgin_general.ipynb',
#  'decorator_example.ipynb',
#  'decotrator_study.ipynb',
#  'Hough_study_20190101.ipynb',
#  'ipython_study_20160213.ipynb',
#  'ipython_study_20170508.ipynb',
#  'json_study.ipynb',
#  'lens_optics.ipynb',
#  'logging_example.ipynb',
#  'machine_learning_20181117.ipynb',
#  'master_pandas_ch3_20160725.ipynb',
#  'master_pandas_ch4_20160726.ipynb',
#  'matplotlib_contour_20181113.ipynb',
#  'nan.csv',
#  'nan_FAIL.csv',
#  'nan_nan.csv',
#  'nan_PASS.csv',
#  'nan_UNSET.csv',
#  'numpy_study_20160214.ipynb',
#  'opencv_self_study_20170327.ipynb',
#  'Pandas_self_study_20170519.ipynb',
#  'Pandas_study_20181216.ipynb',
#  'plot_geometric.ipynb',
#  'python_20180708.ipynb',
#  'python_cookbook_ch1.ipynb',
#  'python_cookbook_ch2.ipynb',
#  'python_cookbook_ch3.ipynb',
#  'python_cookbook_ch5.ipynb',
#  're_study_20160711.ipynb',
#  'seaborn_example.ipynb',
#  'seaborn_example2.ipynb',
#  'Sensor_MTF.ipynb',
#  'SSH_connection.ipynb',
#  'stock_index_closing.csv',
#  'stock_index_prices.csv',
#  'test.py',
#  'TopLeft_SFR_Ny2_H_1_FAIL.csv',
#  'TopLeft_SFR_Ny2_H_1_nan.csv',
#  'TopLeft_SFR_Ny2_H_1_PASS.csv',
#  'TopLeft_SFR_Ny2_H_1_UNSET.csv',
#  'TopLeft_SFR_Ny2_H_2_FAIL.csv',
#  'TopLeft_SFR_Ny2_H_2_nan.csv',
#  'TopLeft_SFR_Ny2_H_2_PASS.csv',
#  'TopLeft_SFR_Ny2_H_2_UNSET.csv',
#  'TopLeft_SFR_Ny2_H_FAIL.csv',
#  'TopLeft_SFR_Ny2_H_nan.csv',
#  'TopLeft_SFR_Ny2_H_PASS.csv',
#  'TopLeft_SFR_Ny2_H_UNSET.csv',
#  'TopLeft_SFR_Ny2_V_1_FAIL.csv',
#  'TopLeft_SFR_Ny2_V_1_nan.csv',
#  'TopLeft_SFR_Ny2_V_1_PASS.csv',
#  'TopLeft_SFR_Ny2_V_1_UNSET.csv',
#  'TopLeft_SFR_Ny2_V_2_FAIL.csv',
#  'TopLeft_SFR_Ny2_V_2_nan.csv',
#  'TopLeft_SFR_Ny2_V_2_PASS.csv',
#  'TopLeft_SFR_Ny2_V_2_UNSET.csv',
#  'TopLeft_SFR_Ny2_V_FAIL.csv',
#  'TopLeft_SFR_Ny2_V_nan.csv',
#  'TopLeft_SFR_Ny2_V_PASS.csv',
#  'TopLeft_SFR_Ny2_V_UNSET.csv',
#  'TopLeft_SFR_Ny4_H_1_FAIL.csv',
#  'TopLeft_SFR_Ny4_H_1_nan.csv',
#  'TopLeft_SFR_Ny4_H_1_PASS.csv',
#  'TopLeft_SFR_Ny4_H_1_UNSET.csv',
#  'TopLeft_SFR_Ny4_H_2_FAIL.csv',
#  'TopLeft_SFR_Ny4_H_2_nan.csv',
#  'TopLeft_SFR_Ny4_H_2_PASS.csv',
#  'TopLeft_SFR_Ny4_H_2_UNSET.csv',
#  'TopLeft_SFR_Ny4_H_FAIL.csv',
#  'TopLeft_SFR_Ny4_H_nan.csv',
#  'TopLeft_SFR_Ny4_H_PASS.csv',
#  'TopLeft_SFR_Ny4_H_UNSET.csv',
#  'TopLeft_SFR_Ny4_V_1_FAIL.csv',
#  'TopLeft_SFR_Ny4_V_1_nan.csv',
#  'TopLeft_SFR_Ny4_V_1_PASS.csv',
#  'TopLeft_SFR_Ny4_V_1_UNSET.csv',
#  'TopLeft_SFR_Ny4_V_2_FAIL.csv',
#  'TopLeft_SFR_Ny4_V_2_nan.csv',
#  'TopLeft_SFR_Ny4_V_2_PASS.csv',
#  'TopLeft_SFR_Ny4_V_2_UNSET.csv',
#  'TopLeft_SFR_Ny4_V_FAIL.csv',
#  'TopLeft_SFR_Ny4_V_nan.csv',
#  'TopLeft_SFR_Ny4_V_PASS.csv',
#  'TopLeft_SFR_Ny4_V_UNSET.csv',
#  'TopRight_SFR_Ny2_H_1_FAIL.csv',
#  'TopRight_SFR_Ny2_H_1_nan.csv',
#  'TopRight_SFR_Ny2_H_1_PASS.csv',
#  'TopRight_SFR_Ny2_H_1_UNSET.csv',
#  'TopRight_SFR_Ny2_H_2_FAIL.csv',
#  'TopRight_SFR_Ny2_H_2_nan.csv',
#  'TopRight_SFR_Ny2_H_2_PASS.csv',
#  'TopRight_SFR_Ny2_H_2_UNSET.csv',
#  'TopRight_SFR_Ny2_H_FAIL.csv',
#  'TopRight_SFR_Ny2_H_nan.csv',
#  'TopRight_SFR_Ny2_H_PASS.csv',
#  'TopRight_SFR_Ny2_H_UNSET.csv',
#  'TopRight_SFR_Ny2_V_1_FAIL.csv',
#  'TopRight_SFR_Ny2_V_1_nan.csv',
#  'TopRight_SFR_Ny2_V_1_PASS.csv',
#  'TopRight_SFR_Ny2_V_1_UNSET.csv',
#  'TopRight_SFR_Ny2_V_2_FAIL.csv',
#  'TopRight_SFR_Ny2_V_2_nan.csv',
#  'TopRight_SFR_Ny2_V_2_PASS.csv',
#  'TopRight_SFR_Ny2_V_2_UNSET.csv',
#  'TopRight_SFR_Ny2_V_FAIL.csv',
#  'TopRight_SFR_Ny2_V_nan.csv',
#  'TopRight_SFR_Ny2_V_PASS.csv',
#  'TopRight_SFR_Ny2_V_UNSET.csv',
#  'TopRight_SFR_Ny4_H_1_FAIL.csv',
#  'TopRight_SFR_Ny4_H_1_nan.csv',
#  'TopRight_SFR_Ny4_H_1_PASS.csv',
#  'TopRight_SFR_Ny4_H_1_UNSET.csv',
#  'TopRight_SFR_Ny4_H_2_FAIL.csv',
#  'TopRight_SFR_Ny4_H_2_nan.csv',
#  'TopRight_SFR_Ny4_H_2_PASS.csv',
#  'TopRight_SFR_Ny4_H_2_UNSET.csv',
#  'TopRight_SFR_Ny4_H_FAIL.csv',
#  'TopRight_SFR_Ny4_H_nan.csv',
#  'TopRight_SFR_Ny4_H_PASS.csv',
#  'TopRight_SFR_Ny4_H_UNSET.csv',
#  'TopRight_SFR_Ny4_V_1_FAIL.csv',
#  'TopRight_SFR_Ny4_V_1_nan.csv',
#  'TopRight_SFR_Ny4_V_1_PASS.csv',
#  'TopRight_SFR_Ny4_V_1_UNSET.csv',
#  'TopRight_SFR_Ny4_V_2_FAIL.csv',
#  'TopRight_SFR_Ny4_V_2_nan.csv',
#  'TopRight_SFR_Ny4_V_2_PASS.csv',
#  'TopRight_SFR_Ny4_V_2_UNSET.csv',
#  'TopRight_SFR_Ny4_V_FAIL.csv',
#  'TopRight_SFR_Ny4_V_nan.csv',
#  'TopRight_SFR_Ny4_V_PASS.csv',
#  'TopRight_SFR_Ny4_V_UNSET.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'word_count.ipynb']

# %%
import demo

# %%
demo.c
# Out:
# 2

# %%
demo.print_a()
# Out:
# a

# %%
demo?

# %%
who
# Out:
# demo	 funcname	 message	 os	 variable_args	 word

# %%
dir(demo)
# Out:
# ['__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'c',
#  'd',
#  'print_a',
#  'print_b']

# %%
import numpy as np

# %%
L = range(1000)

# %%
# %timeit [i**2 for i in L]
# Out:
# 10000 loops, best of 3: 43.2 µs per loop

# %%
a = np.arange(1000)

# %%
# %timeit a**2
# Out:
# The slowest run took 30.12 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 1.1 µs per loop

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (3L,)

# %%
len(a)
# Out:
# 3

# %%
c = np.array([[[1], [2]], [[3], [4]]])

# %%
c.shape
# Out:
# (2L, 2L, 1L)

# %%
a.dtype
# Out:
# dtype('int32')

# %%
import logging

# %%
FORMAT = '%(asctime)-15s %(clientip)s %(user)-8s %(message)s'
logging.basicConfig(format=FORMAT)
d = {'clientip': '192.168.0.1', 'user': 'fbloggs'}
logger = logging.getLogger('tcpserver')
logger.warning('Protocol problem: %s', 'connection reset', extra=d)
# Out:
# 2019-01-03 15:56:48,944 192.168.0.1 fbloggs  Protocol problem: connection reset

# %%
def variable_args(*args, **kwargs):
    print 'args is', args
    print 'kwargs is', kwargs

# %%
variable_args('one', 'two', x=1, y=2, z=3)
# Out:
# args is ('one', 'two')
# kwargs is {'y': 2, 'x': 1, 'z': 3}

# %%
# %matplotlib inline

# %%
import matplotlib.pylab as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 3, 20)
y = np.linspace(0, 9, 20)
plt.plot(x, y)

# %%
plt.plot(x, y, '-o')

# %%
data = np.loadtxt(r'population.txt')
year, h, l, c=data.T

# %%
# plt.axes([0.2, 0.1, 0.5, 0.8])
plt.plot(year, h, year, l, year, c)
plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05, 0.5))

# %%
populations = data[:, 1:]

# %%
populations
# Out:
# array([[30000.,  4000., 48300.],
#        [47200.,  6100., 48200.],
#        [70200.,  9800., 41500.],
#        [77400., 35200., 38200.],
#        [36300., 59400., 40600.],
#        [20600., 41700., 39800.],
#        [18100., 19000., 38600.],
#        [21400., 13000., 42300.],
#        [22000.,  8300., 44500.],
#        [25400.,  9100., 42100.],
#        [27100.,  7400., 46000.],
#        [40300.,  8000., 46800.],
#        [57000., 12300., 43800.],
#        [76600., 19500., 40900.],
#        [52300., 45700., 39400.],
#        [19500., 51100., 39000.],
#        [11200., 29700., 36700.],
#        [ 7600., 15800., 41800.],
#        [14600.,  9700., 43300.],
#        [16200., 10100., 41300.],
#        [24700.,  8600., 47300.]])

# %%
x, y = np.arange(5), np.arange(5)[:, np.newaxis]

# %%
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
y
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4]])

# %%
distance = np.sqrt(x ** 2 + y ** 2)
distance
# Out:
# array([[0.        , 1.        , 2.        , 3.        , 4.        ],
#        [1.        , 1.41421356, 2.23606798, 3.16227766, 4.12310563],
#        [2.        , 2.23606798, 2.82842712, 3.60555128, 4.47213595],
#        [3.        , 3.16227766, 3.60555128, 4.24264069, 5.        ],
#        [4.        , 4.12310563, 4.47213595, 5.        , 5.65685425]])

# %%
plt.pcolor(distance)
plt.colorbar()

# %%
p = np.poly1d([3, 2, -1])
p(0)
# Out:
# -1

# %%
p.roots
# Out:
# array([-1.        ,  0.33333333])

# %%
x = np.linspace(0, 1, 20)
y = np.cos(x) + 0.3*np.random.rand(20)
p = np.poly1d(np.polyfit(x, y, 3))
t = np.linspace(0, 1, 200)
plt.plot(x, y, 'o', t, p(t), '-')
# Out:
# [<matplotlib.lines.Line2D at 0x1ea9e588>,
#  <matplotlib.lines.Line2D at 0x1ea9e5f8>]

# %%
x = np.linspace(-1, 1, 2000)
>>> y = np.cos(x) + 0.3*np.random.rand(2000)
>>> p = np.polynomial.Chebyshev.fit(x, y, 90)
>>> t = np.linspace(-1, 1, 200)
>>> plt.plot(x, y, 'r.')
plt.plot(t, p(t), 'k-', lw=3)

# %%
from scipy import misc
>>> face = misc.face(gray=True) # 2D grayscale image

# %%
plt.imshow(face)

# %%
plt.imshow(face, cmap=plt.cm.gray)

# %%
crop_face = face[100:200, :]

# %%
plt.imshow(crop_face, cmap=plt.cm.gray)

# %%
image = np.random.rand(30, 30)
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C)
plt.plot(X, S)
plt.show()

# %%
# Create a figure of size 8x6 inches, 80 dots per inch
plt.figure(figsize=(8, 6), dpi=80)
# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
# Plot cosine with a blue continuous line of width 1 (pixels)
plt.plot(X, C,  linewidth=1.0, linestyle="-")
# plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
# Plot sine with a green continuous line of width 1 (pixels)
plt.plot(X, S,  linewidth=1.0, linestyle="-")
# plt.plot(X, S, color="red", linewidth=1.0, linestyle="-")
# Set x limits
plt.xlim(-4.0, 4.0)
# Set x ticks
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))
# Set y limits
plt.ylim(-1.0, 1.0)
# Set y ticks
plt.yticks(np.linspace(-1, 1, 5, endpoint=True))
# Save figure using 72 dots per inch
# plt.savefig("exercise_2.png", dpi=72)
# Show result on screen
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
# Plot cosine with a blue continuous line of width 1 (pixels)
plt.plot(X, C,  linewidth=1.0, linestyle="-", label="cosine")
# plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
# Plot sine with a green continuous line of width 1 (pixels)
plt.plot(X, S,  linewidth=1.0, linestyle="-")
# plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1])
ax = plt.gca() # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.legend(loc='upper left')

# %%
Z = np.random.uniform(0, 1, 20)
plt.pie(Z)
# Out:
# ([<matplotlib.patches.Wedge at 0x2f066898>,
#   <matplotlib.patches.Wedge at 0x2f066e10>,
#   <matplotlib.patches.Wedge at 0x2e7c3208>,
#   <matplotlib.patches.Wedge at 0x2f35c9e8>,
#   <matplotlib.patches.Wedge at 0x2f4bc710>,
#   <matplotlib.patches.Wedge at 0x2f4bc6d8>,
#   <matplotlib.patches.Wedge at 0x2f4bc3c8>,
#   <matplotlib.patches.Wedge at 0x2f4d79b0>,
#   <matplotlib.patches.Wedge at 0x2f4d74e0>,
#   <matplotlib.patches.Wedge at 0x2f4d7438>,
#   <matplotlib.patches.Wedge at 0x2eedb978>,
#   <matplotlib.patches.Wedge at 0x2f380588>,
#   <matplotlib.patches.Wedge at 0x2f3805c0>,
#   <matplotlib.patches.Wedge at 0x30a53c18>,
#   <matplotlib.patches.Wedge at 0x30315128>,
#   <matplotlib.patches.Wedge at 0x303155f8>,
#   <matplotlib.patches.Wedge at 0x30315a90>,
#   <matplotlib.patches.Wedge at 0x30315f60>,
#   <matplotlib.patches.Wedge at 0x3030d470>,
#   <matplotlib.patches.Wedge at 0x3030d940>],
#  [Text(1.09775,0.0703936,u''),
#   Text(1.01282,0.429175,u''),
#   Text(0.669683,0.872654,u''),
#   Text(0.377817,1.03308,u''),
#   Text(0.274014,1.06532,u''),
#   Text(0.123962,1.09299,u''),
#   Text(-0.0100388,1.09995,u''),
#   Text(-0.343889,1.04486,u''),
#   Text(-0.705106,0.84429,u''),
#   Text(-0.879059,0.661252,u''),
#   Text(-1.06382,0.279813,u''),
#   Text(-1.04764,-0.335325,u''),
#   Text(-0.857589,-0.688869,u''),
#   Text(-0.739756,-0.814101,u''),
#   Text(-0.394276,-1.02691,u''),
#   Text(0.257402,-1.06946,u''),
#   Text(0.607463,-0.917054,u''),
#   Text(0.689551,-0.857041,u''),
#   Text(0.834962,-0.716127,u''),
#   Text(1.04941,-0.329768,u'')])

# %%
fig = plt.figure()
fig.subplots_adjust(bottom=0.025, left=0.025, top = 0.975, right=0.975)
plt.subplot(2, 1, 1)
plt.xticks(()), plt.yticks(())
plt.subplot(2, 3, 4)
plt.xticks(())
plt.yticks(())
plt.subplot(2, 3, 5)
plt.xticks(())
plt.yticks(())
plt.subplot(2, 3, 6)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
n = 20
Z = np.ones(n)
Z[-1] *= 2
plt.axes([0.025, 0.025, 0.95, 0.95])
plt.pie(Z, explode=Z*.05, colors = ['%f ' % (i/float(n)) for i in range(n)])
plt.axis('equal')
plt.xticks(())
plt.yticks()
plt.show()

# %%
plt.subplot(3, 1, 1)
plt.xticks(()), plt.yticks(())
plt.subplot(3, 2, 3)
plt.xticks(())
plt.yticks(())
plt.subplot(3, 2, 4)
plt.xticks(())
plt.yticks(())
plt.subplot(3,3, 7)
plt.xticks(())
plt.yticks(())
plt.subplot(3,3, 8)
plt.xticks(())
plt.yticks(())
plt.subplot(3,3, 9)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.axes([.1, .1, .8, .8])
plt.xticks(())
plt.yticks(())
plt.text(.6, .6, 'axes([0.1, 0.1, .8, .8])', ha='center', va='center',
size=20, alpha=.5)
plt.axes([.15, .2, .3, .4])
plt.xticks(())
plt.yticks(())
plt.text(.5, .5, 'axes([0.2, 0.2, .3, .3])', ha='center', va='center',
size=16, alpha=.5)
# Out:
# Text(0.5,0.5,'axes([0.2, 0.2, .3, .3])')

# %%
from scipy import io as spio

# %%
import numpy as np

# %%
a = np.ones((3, 3))

# %%
a
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
import threading

# %%
def hello():
    print "hello, world"

# %%
t = threading.Timer(5, hello)

# %%
t.start()
# Out:
# hello, world

# %%
def simple_decorator(function):
    print("doing decoration")
    return function

# %%
@simple_decorator
def function():
    print("inside function")
# Out:
# doing decoration

# %%
function()
# Out:
# inside function
