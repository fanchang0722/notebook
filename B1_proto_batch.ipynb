# %%
import sys
import os
import time
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import subprocess as sub
import matplotlib.pylab as plt

# %%
os.getcwd()
# Out:
# '/Users/fanchang/notebook'

# %%
fp = open(r'/Users/fanchang/notebook/B1_rear_10m_SFR_list', 'r')
fout = open('B1_proto_rear_10m_SFR.csv', 'w')
fout.writelines('SN,Date,cent_0,cent_1,cent_2,cent_3,TL_30_0,TL_30_1,TL_30_2,TL_30_3,TR_30_0,TR_30_1,TR_30_2,TR_30_3,BR_30_0,BR_30_1,BR_30_2,BR_30_3,BL_30_0,BL_30_1,BL_30_2,BL_30_3\r\n')
for line in fp:
    tempname = line.split('/')
#     print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Cen_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
        if lines.startswith('Cen_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('RT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_front_NFOV_SFR_list', 'r')
fout = open('B1_proto_front_NFOV_10m_SFR.csv', 'w')
fout.writelines('SN,Date,cent_0,cent_1,cent_2,cent_3,TL_30_0,TL_30_1,TL_30_2,TL_30_3,TR_30_0,TR_30_1,TR_30_2,TR_30_3,BR_30_0,BR_30_1,BR_30_2,BR_30_3,BL_30_0,BL_30_1,BL_30_2,BL_30_3\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Cen_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
        if lines.startswith('Cen_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('RT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_front_wide_SFR_list', 'r')
fout = open('B1_proto_front_WFOV_65cm_SFR.csv', 'w')
fout.writelines('SN,Date,cent_0,cent_1,cent_2,cent_3,TL_30_0,TL_30_1,TL_30_2,TL_30_3,TR_30_0,TR_30_1,TR_30_2,TR_30_3,BR_30_0,BR_30_1,BR_30_2,BR_30_3,BL_30_0,BL_30_1,BL_30_2,BL_30_3\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Cen_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
        if lines.startswith('Cen_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('Cen_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('LT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
            temp = ' '
            temp2 = ' '

        if lines.startswith('RT_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RT_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('RB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_0'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_1'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_2'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','

        if lines.startswith('LB_30_3'):
            temp =lines.strip('\r\n').split('=')[1]
            temp2 = temp.split(',')
            output += str(temp2[0]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_front_NFOV_AWB_list', 'r')
fout = open('B1_proto_front_NFOV_AWB.csv', 'w')
fout.writelines('SN,Date,BbyGb,RbyGr, GrbyGb\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('BbyGb'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('RbyGr'):
            temp =lines.strip('\r\n').split('=')
            output += str(temp[1]) + ','
        if lines.startswith('GrbyGb'):
            temp =lines.strip('\r\n').split('=')
            output += str(temp[1]) + ','
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_NFOV_light_5100_blemish_list', 'r')
fout = open('B1_proto_front_NFOV_5100_blemish.csv', 'w')
fout.writelines('SN,Date,Blemish\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Blemish'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000X2,20171024, 3.0,
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WQ,20171024, 3.0,
# 7AQX000WP_COMBO2017102418154200
# 7AQX000WP,20171024, 1.0,
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UF,20171024, 0.0,
# 7AMX000UD_COMBO2017102416572300
# 7AMX000UD,20171024, 1.0,
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TK,20171024, 0.0,
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TJ,20171022, 1.0,
# 7AMX000TE_COMBO2017102216113900
# 7AMX000TE,20171022, 0.0,
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SY,20171022, 1.0,
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SW,20171022, 0.0,
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SS,20171022, 0.0,
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SQ,20171022, 0.0,
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SP,20171021, 0.0,
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SL,20171023, 2.0,
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SH,20171022, 0.0,
# 7ALX000SG_COMBO2017102217494100
# 7ALX000SG,20171022, 0.0,
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_WFOV_light_5100_blemish_list', 'r')
fout = open('B1_proto_front_WFOV_5100_blemish.csv', 'w')
fout.writelines('SN,Date,Blemish\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Blemish'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000X2,20171024, 246.0,
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WQ,20171024, 260.0,
# 7AQX000WP_COMBO2017102418154200
# 7AQX000WP,20171024, 255.0,
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UF,20171024, 248.0,
# 7AMX000UD_COMBO2017102416572300
# 7AMX000UD,20171024, 254.0,
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TK,20171024, 241.0,
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TJ,20171022, 201.0,
# 7AMX000TE_COMBO2017102216113900
# 7AMX000TE,20171022, 176.0,
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SY,20171022, 190.0,
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SW,20171022, 171.0,
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SS,20171022, 169.0,
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SQ,20171022, 198.0,
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SL,20171023, 222.0,
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SH,20171022, 201.0,
# 7ALX000SG_COMBO2017102217494100
# 7ALX000SG,20171022, 189.0,
# 7ALX000S6_COMBO2017102215535900
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_NFOV_light_5100_OC_list', 'r')
fout = open('B1_proto_front_NFOV_5100_OC.csv', 'w')
fout.writelines('SN,Date,SHIFT_R\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('SHIFT_R'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
    print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000X2,20171024, 11.1209626772,
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WQ,20171024, 6.73099355941,
# 7AQX000WP_COMBO2017102418154200
# 7AQX000WP,20171024, 4.74297947472,
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UF,20171024, 9.03691870208,
# 7AMX000UD_COMBO2017102416572300
# 7AMX000UD,20171024, 8.23824487407,
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TK,20171024, 22.1225037983,
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TJ,20171022, 16.6383534346,
# 7AMX000TE_COMBO2017102216113900
# 7AMX000TE,20171022, 2.21780390969,
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SY,20171022, 6.93189936969,
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SW,20171022, 13.86071833,
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SS,20171022, 17.9451044476,
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SQ,20171022, 19.8331205596,
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SP,20171021, 186.454377697,
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SL,20171023, 15.3752205073,
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_WFOV_light_5100_OC_list', 'r')
fout = open('B1_proto_front_WFOV_5100_OC.csv', 'w')
fout.writelines('SN,Date,SHIFT_R\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('SHIFT_R'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# 7ALX000R0_COMBO2017102211002000
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_WFOV_light_5000_RI_list', 'r')
fout = open('B1_proto_front_WFOV_5100_RI.csv', 'w')
fout.writelines('SN,Date,TL,TR,BL,BR\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('TL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('TR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# 7ALX000R0_COMBO2017102211002000
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_NFOV_light_5000_RI_list', 'r')
fout = open('B1_proto_front_NFOV_5100_RI.csv', 'w')
fout.writelines('SN,Date,TL,TR,BL,BR\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('TL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('TR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SP_COMBO2017102120383800
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_rear_RI_list', 'r')
fout = open('B1_proto_rear_RI.csv', 'w')
fout.writelines('SN,Date,TL,TR,BL,BR\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('TL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('TR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BL'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
        if lines.startswith('BR'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# 7ALX000R0_COMBO2017102211002000
# ...

# %%
fp = open(r'/Users/fanchang/notebook/B1_proto_rear_blemish_list', 'r')
fout = open('B1_proto_rear_blemish.csv', 'w')
fout.writelines('SN,Date,Blemish\r\n')
for line in fp:
    tempname = line.split('/')
    print tempname[5]
    tempname2 = tempname[5].split('_')
#     print tempname2[0], str(tempname2[1][5:13])
    fid = open(line.rstrip('\r\n'), 'r')
    output = tempname2[0] + ',' + str(tempname2[1][5:13]) + ','
    for lines in fid:
        if lines.startswith('Blemish'):
            temp =lines.strip('\r\n').split('=')          
            output += str(temp[1]) + ','
#     print output
    fout.writelines(output+'\r\n')
fout.close()
# Out:
# 7AQX000X2_COMBO2017102418240100
# 7AQX000WQ_COMBO2017102417293900
# 7AQX000WP_COMBO2017102418154200
# 7AMX000UF_COMBO2017102417074500
# 7AMX000UD_COMBO2017102416572300
# 7AMX000TK_COMBO2017102418001400
# 7AMX000TJ_COMBO2017102215472800
# 7AMX000TE_COMBO2017102216113900
# 7ALX000SY_COMBO2017102217595000
# 7ALX000SW_COMBO2017102210002700
# 7ALX000SS_COMBO2017102217055600
# 7ALX000SQ_COMBO2017102217311200
# 7ALX000SL_COMBO2017102316480400
# 7ALX000SH_COMBO2017102208210500
# 7ALX000SG_COMBO2017102217494100
# 7ALX000S6_COMBO2017102215535900
# 7ALX000S3_COMBO2017102120234400
# 7ALX000S2_COMBO2017102315201000
# 7ALX000S1_COMBO2017102210234500
# 7ALX000S0_COMBO2017102416413900
# 7ALX000RZ_COMBO2017102310191300
# 7ALX000RU_COMBO2017102215302400
# 7ALX000RR_COMBO2017102218063200
# 7ALX000RP_COMBO2017102211102600
# 7ALX000R2_COMBO2017102117250900
# 7ALX000R2_COMBO2017102019153100
# 7ALX000R1_COMBO2017102117033500
# 7ALX000R1_COMBO2017102019303900
# 7ALX000R0_COMBO2017102211002000
# ...

# %%
listname=!ls

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# !load_ext rmagic
# Out:
# /bin/sh: load_ext: command not found

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: /Users/fanchang/notebook
